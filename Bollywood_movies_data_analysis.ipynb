# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin-31121999/Data-Analysis-Practice/blob/main/Bollywood_movies_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt

# %%
movies=pd.read_csv("/content/movies (1).csv")
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl=pd.read_csv("/content/ipl-matches (1).csv")
ipl.set_index("ID")
ipl.iloc[0:3,0:5]
# Out:
#         ID       City        Date Season  MatchNumber
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator

# %%
batsman=pd.read_csv("/content/batsman_runs_ipl (1).csv")
bats=batsman.set_index("batter")
bats["Batting Rank"]=bats["batsman_run"].rank(ascending=False).sort_values()
a=bats.sort_values("Batting Rank").head(50).reset_index()
a
# Out:
#             batter  batsman_run  Batting Rank
# 0          V Kohli         6634           1.0
# 1         S Dhawan         6244           2.0
# 2        DA Warner         5883           3.0
# 3        RG Sharma         5881           4.0
# 4         SK Raina         5536           5.0
# 5   AB de Villiers         5181           6.0
# 6         CH Gayle         4997           7.0
# 7         MS Dhoni         4978           8.0
# 8       RV Uthappa         4954           9.0
# 9       KD Karthik         4377          10.0
# 10       G Gambhir         4217          11.0
# 11       AT Rayudu         4190          12.0
# 12       AM Rahane         4074          13.0
# 13        KL Rahul         3895          14.0
# 14       SR Watson         3880          15.0
# 15       MK Pandey         3657          16.0
# 16       SV Samson         3526          17.0
# 17      KA Pollard         3437          18.0
# 18    F du Plessis         3403          19.0
# ...

# %%
b=a[["batter","batsman_run"]]
b.set_index("batter")
b
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-10e1d6913137> in <cell line: 1>()
# ----> 1 b=a[["batter","batsman_run"]]
#       2 b.set_index("batter")
#       3 b
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
movies.sort_values(["title_x","year_of_release"],ascending=[False,True])
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl[~ipl["MatchNumber"].str.isdigit()][["Season","MatchNumber","Team1","Team2","TossWinner","WinningTeam","Player_of_Match"]].set_index("Season")
# Out:
#                 MatchNumber                        Team1  \
# Season
# 2022                  Final             Rajasthan Royals
# 2022            Qualifier 2  Royal Challengers Bangalore
# 2022             Eliminator  Royal Challengers Bangalore
# 2022            Qualifier 1             Rajasthan Royals
# 2021                  Final          Chennai Super Kings
# 2021            Qualifier 2               Delhi Capitals
# 2021             Eliminator  Royal Challengers Bangalore
# 2021            Qualifier 1               Delhi Capitals
# 2020/21               Final               Delhi Capitals
# 2020/21         Qualifier 2               Delhi Capitals
# 2020/21          Eliminator  Royal Challengers Bangalore
# 2020/21         Qualifier 1               Mumbai Indians
# 2019                  Final               Mumbai Indians
# 2019              Qualifier               Delhi Capitals
# 2019             Eliminator          Sunrisers Hyderabad
# ...

# %%
movies.rename(columns={"imbd_id":"imbd","poster_path":"link"},inplace=True)
mo=movies.set_index("title_x",inplace=True)
mo

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[ipl["SuperOver"]=="Y"].shape[0]
# Out:
# 14
