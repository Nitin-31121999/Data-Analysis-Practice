# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin-31121999/Data-Analysis-Practice/blob/main/Data_Visualization_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import missingno as ms
import seaborn as sns

# %%
iris=pd.read_csv("iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris["Species"]=iris["Species"].replace({"Iris-setosa":0,"Iris-virginica":1,"Iris-versicolor":2})
iris
# Out:
# <ipython-input-15-b59e66f22534>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris["Species"]=iris["Species"].replace({"Iris-setosa":0,"Iris-virginica":1,"Iris-versicolor":2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# ...

# %%
iris.sample(16)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 15    16            5.7           4.4            1.5           0.4        0
# 91    92            6.1           3.0            4.6           1.4        2
# 28    29            5.2           3.4            1.4           0.2        0
# 95    96            5.7           3.0            4.2           1.2        2
# 82    83            5.8           2.7            3.9           1.2        2
# 56    57            6.3           3.3            4.7           1.6        2
# 144  145            6.7           3.3            5.7           2.5        1
# 140  141            6.7           3.1            5.6           2.4        1
# 53    54            5.5           2.3            4.0           1.3        2
# 61    62            5.9           3.0            4.2           1.5        2
# 23    24            5.1           3.3            1.7           0.5        0
# ...

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"])
plt.colorbar()

# %%
df=pd.read_csv("/content/batter (1).csv")
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
sample_df=df.head(50).sample(25)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 42  KS Williamson  2105  36.293103   123.315759
# 3       RG Sharma  5881  30.314433   126.964594
# 8      RV Uthappa  4954  27.522222   126.152279
# 40         N Rana  2181  27.961538   130.053667
# 30      RA Jadeja  2502  26.617021   122.108346
# 35        WP Saha  2427  25.281250   124.397745
# 26   Yuvraj Singh  2754  24.810811   124.784776
# 47     MEK Hussey  1977  38.764706   119.963592
# 38   SR Tendulkar  2334  33.826087   114.187867
# 9      KD Karthik  4377  26.852761   129.267572
# 36       DR Smith  2385  28.392857   132.279534
# 1        S Dhawan  6244  34.882682   122.840842
# 34      JH Kallis  2427  28.552941   105.936272
# 11      AT Rayudu  4190  28.896552   124.148148
# 12      AM Rahane  4074  30.863636   117.575758
# 16      SV Samson  3526  29.140496   132.407060
# 33      DA Miller  2455  36.102941   133.569097
# 41       R Dravid  2174  28.233766   113.347237
# 25      Q de Kock  2767  31.804598   130.951254
# ...

# %%
plt.figure(figsize=(16,8))
plt.scatter(sample_df["avg"],sample_df["strike_rate"],s=sample_df["runs"])
plt.xlabel("average")
plt.ylabel("strike rate")
plt.axhline(130,color="red")
plt.axvline(35,color="red")
for i in range(sample_df.shape[0]):
  plt.text(sample_df["avg"].values[i],sample_df["strike_rate"].values[i],sample_df["batter"].values[i])

# %%
fig,ax=plt.subplots(figsize=(10,6))
ax.scatter(df["avg"],df["strike_rate"])
ax.set_xlabel("average")
ax.set_ylabel("strike rate")
# Out:
# Text(0, 0.5, 'strike rate')

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,6))
ax[0].scatter(sample_df["runs"],sample_df["avg"],color="red",marker="D")

ax[0].set_xlabel("runs")
ax[0].set_ylabel("average")
ax[1].scatter(sample_df["runs"],sample_df["strike_rate"])
ax[1].set_xlabel("runs")
ax[1].set_ylabel("strike rate")
# Out:
# Text(0, 0.5, 'strike rate')
