# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin-31121999/Data-Analysis-Practice/blob/main/IPL_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ipl=pd.read_csv("/content/ipl-matches (1).csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies=pd.read_csv("/content/movies (1).csv")
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
dict={
    "NAME":["Nitin","Nikhil","Neha","Nitish"],"IQ":[80,100,200,100],"MARKS":[100,100,90,100],"PACKAGE":[27,78,98,98]

}
df=pd.DataFrame(dict)
df.set_index("NAME")
# Out:
#          IQ  MARKS  PACKAGE
# NAME
# Nitin    80    100       27
# Nikhil  100    100       78
# Neha    200     90       98
# Nitish  100    100       98

# %%
df['IQ'].value_counts()
# Out:
# IQ
# 100    2
# 80     1
# 200    1
# Name: count, dtype: int64

# %%
df
# Out:
#      NAME   IQ  MARKS  PACKAGE
# 0   Nitin   80    100       27
# 1  Nikhil  100    100       78
# 2    Neha  200     90       98
# 3  Nitish  100    100       98

# %%
ipl.head(3)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[~ipl["MatchNumber"].str.isdigit()][["MatchNumber","Season","Player_of_Match"]].sort_index().set_index("MatchNumber")
# Out:
#                      Season    Player_of_Match
# MatchNumber
# Final                  2022          HH Pandya
# Qualifier 2            2022         JC Buttler
# Eliminator             2022         RM Patidar
# Qualifier 1            2022          DA Miller
# Final                  2021       F du Plessis
# Qualifier 2            2021            VR Iyer
# Eliminator             2021          SP Narine
# Qualifier 1            2021         RD Gaikwad
# Final               2020/21           TA Boult
# Qualifier 2         2020/21         MP Stoinis
# Eliminator          2020/21      KS Williamson
# Qualifier 1         2020/21          JJ Bumrah
# Final                  2019          JJ Bumrah
# Qualifier              2019       F du Plessis
# Eliminator             2019            RR Pant
# Qualifier              2019           SA Yadav
# Final                  2018          SR Watson
# Qualifier              2018        Rashid Khan
# Eliminator             2018         AD Russell
# ...

# %%
ipl[~ipl["MatchNumber"].str.isdigit()][["Player_of_Match"]].sort_index().value_counts().astype("int32")
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# A Kumble             2
# SR Watson            2
# MK Pandey            2
# M Vijay              2
# JJ Bumrah            2
# YK Pathan            2
# AB de Villiers       2
# DA Warner            1
# SA Yadav             1
# NM Coulter-Nile      1
# RD Gaikwad           1
# RG Sharma            1
# RM Patidar           1
# RR Pant              1
# Rashid Khan          1
# AC Gilchrist         1
# DE Bollinger         1
# SP Narine            1
# TA Boult             1
# UT Yadav             1
# V Sehwag             1
# VR Iyer              1
# Washington Sundar    1
# MS Dhoni             1
# MS Bisla             1
# MP Stoinis           1
# KH Pandya            1
# DA Miller            1
# HH Pandya            1
# Harbhajan Singh      1
# JC Buttler           1
# CH Gayle             1
# BJ Hodge             1
# KS Williamson        1
# MM Patel             1
# KV Sharma            1
# ...

# %%
ipl.sample(7)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 463   829723    Kolkata  2015-04-30     2015          30
# 207  1178422    Kolkata  2019-04-28     2019          47
# 253  1175356    Chennai  2019-03-23     2019           1
# 326  1082638  Hyderabad  2017-05-08     2017          48
# 154  1216518        NaN  2020-10-22  2020/21          40
# 775   419165     Mumbai  2010-04-25  2009/10       Final
# 646   548363    Kolkata  2012-05-12     2012          58
#
#                            Team1                Team2  \
# 463        Kolkata Knight Riders  Chennai Super Kings
# 207        Kolkata Knight Riders       Mumbai Indians
# 253  Royal Challengers Bangalore  Chennai Super Kings
# 326          Sunrisers Hyderabad       Mumbai Indians
# 154             Rajasthan Royals  Sunrisers Hyderabad
# 775          Chennai Super Kings       Mumbai Indians
# 646        Kolkata Knight Riders       Mumbai Indians
#
# ...

# %%
ipl["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
ipl["WinningTeam"].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
(ipl["Team1"].value_counts())+(ipl["Team2"].value_counts()).sort_values(ascending=False)
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values("title_x",ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(["title_x","year_of_release"],ascending=[True,False])
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
batsman=pd.read_csv("/content/batsman_runs_ipl (1).csv")
batsman.set_index("batter",inplace=True)
batsman.sort_values("batsman_run",ascending=False).head(10)
# Out:
#                 batsman_run
# batter
# V Kohli                6634
# S Dhawan               6244
# DA Warner              5883
# RG Sharma              5881
# SK Raina               5536
# AB de Villiers         5181
# CH Gayle               4997
# MS Dhoni               4978
# RV Uthappa             4954
# KD Karthik             4377

# %%
bats=pd.read_csv("/content/batsman_runs_ipl (1).csv")
bats["batting_rank"]=bats["batsman_run"].rank(ascending=False)
bats.sort_values("batting_rank",ascending=True)
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]
